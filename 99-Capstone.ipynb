# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Databricks Partner Capstone Project
#
# This optional capstone is included in the course to help you solidify key topics related to Databricks, Structured Streaming, and Delta.

# %% [markdown]
# # Capstone Overview
#
# In this project you will build a Delta Lake over incoming Streaming Data by using a series of Bronze, Silver, and Gold Tables.
#
# The Goal of the project is to gain actionable insights from a data lake, using a series of connected tables that:
# * Preserve the raw data
# * Enrich the data by joining with additional static table
# * Use Structured Streaming along with Delta tables to guarantee a robust solution
#
# ### Scenario:
#
# A video gaming company stores historical data in a data lake, which is growing exponentially.
#
# The data isn't sorted in any particular way (actually, it's quite a mess).
#
# It is proving to be _very_ difficult to query and manage this data because there is so much of it.
#
#
# ## Instructions
# 1. Read in streaming data into Databricks Delta bronze tables
# 2. Create Databricks Delta silver table
# 3. Compute aggregate statistics about data i.e. create gold table

# %% [markdown]
# -sandbox
#
# ## What is a table?
# Before we continue, we need to address a semantic concern addressed by the [Databricks docs](https://docs.databricks.com/user-guide/tables.html#view-databases-and-tables):
#
# > A Databricks table is a collection of structured data. Tables are equivalent to Apache Spark DataFrames.
#
# Generally, the distinction between tables and DataFrames in Spark can be summarized by discussing scope and persistence:
# - Tables are defined at the **workspace** level and **persist** between notebooks.
# - DataFrames are defined at the **notebook** level and are **ephemeral**.
#
# When we discuss **Delta tables**, we are always talking about collections of structured data that persist between notebooks. Importantly, we do not need to register a directory of files to Spark SQL in order to refer to them as a table. The directory of files itself _is_ the table; registering it with a useful name to Spark SQL just gives us easy accessing to querying these underlying data.
#
# A **Delta Lake** can be thought of as a collection of one or many Delta tables. Generally, an entire elastic storage container will be dedicated to a single Delta Lake, and data will be enriched and cleaned as it is promoted through pre-defined logic.
#
# <img alt="Best Practice" title="Best Practice" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-blue-ribbon.svg"/> To make Delta tables easily accessible, register them using Spark SQL. Use table ACLs to control access in workspaces shared by many diverse parties within an organization.

# %% [markdown]
# ## Getting Started
#
# Run the following cell to configure our environment.

# %%
# %run "./Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Initialized classroom variables & functions...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training-us-east-1/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Imported Test Library...
# Created user-specific database
# Using the database <b style="color:green">akarsh_pydimarri_wavicledata_com_db</b>.
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# All done!

# %% [markdown]
# -sandbox
#
# ### Set up paths
#
# The cell below sets up relevant paths in DBFS.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> It also clears out this directory (to ensure consistent results if re-run). This operation can take several minutes.

# %%
inputPath = "/mnt/training/gaming_data/mobile_streaming_events"

basePath = userhome + "/capstone"
outputPathBronze = basePath + "/gaming/bronze"
outputPathSilver = basePath + "/gaming/silver"
outputPathGold   = basePath + "/gaming/gold"

dbutils.fs.rm(basePath, True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>True</div>

# %% [markdown]
# ### SQL Table Setup
#
# The follow cell drops a table that we'll be creating later in the notebook.
#
# (Dropping the table prevents challenges involved if the notebook is run more than once.)

# %%
# %sql
DROP TABLE IF EXISTS mobile_events_delta_gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Step 1: Prepare Schema and Read Streaming Data from input source
#
# The input source is a folder containing 20 files of around 50 MB each.
#
# The stream is configured to read one file per trigger.
#
# Run this code to start the streaming read from the file directory.

# %%
from pyspark.sql.types import StructType, StringType, IntegerType, TimestampType, DoubleType

eventSchema = ( StructType()
  .add('eventName', StringType()) 
  .add('eventParams', StructType() 
    .add('game_keyword', StringType()) 
    .add('app_name', StringType()) 
    .add('scoreAdjustment', IntegerType()) 
    .add('platform', StringType()) 
    .add('app_version', StringType()) 
    .add('device_id', StringType()) 
    .add('client_event_time', TimestampType()) 
    .add('amount', DoubleType()) 
  )     
)

gamingEventDF = (spark
  .readStream
  .schema(eventSchema) 
  .option('streamName','mobilestreaming_demo') 
  .option("maxFilesPerTrigger", 1)                # treat each file as Trigger event
  .json(inputPath) 
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# ### Step 2: Write Stream to Bronze Table
#
# Write some code that performs the following tasks
#
# * Write the stream from `gamingEventDF` -- the stream defined above -- to a bronze Delta table in path defined by `outputPathBronze`.
# * Convert the input column `client_event_time` to a date format and rename the column to `eventDate`
# * Filter out records with a null value in the `eventDate` column
# * Make sure you provide a checkpoint directory that is unique to this stream
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Using `append` mode when streaming allows us to insert data indefinitely without rewriting already processed data.

# %%
###IGNORE CELL-for testing purposes

gamingEventDF.printSchema()


#from pyspark.sql.functions import to_date
#df = spark.createDataFrame([('1997-02-28 10:30:00',)], ['t'])
#display(df)
#display(df.select(to_date(df.t).alias('date')).collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- eventName: string (nullable = true)
# -- eventParams: struct (nullable = true)
#     |-- game_keyword: string (nullable = true)
#     |-- app_name: string (nullable = true)
#     |-- scoreAdjustment: integer (nullable = true)
#     |-- platform: string (nullable = true)
#     |-- app_version: string (nullable = true)
#     |-- device_id: string (nullable = true)
#     |-- client_event_time: timestamp (nullable = true)
#     |-- amount: double (nullable = true)
#
# </div>

# %%
###IGNORE CELL-for testing purposes

from pyspark.sql.functions import col
#print(gamingEventDF.withColumnRenamed("eventParams.client_event_time","eventDate").dtypes) #######with columns renamed doesn't work for nested columns
#testdf = gamingEventDF.select("eventName",gamingEventDF.eventParams.client_event_time.alias("abc"))  #######flattening it out

###to date
#testdf = gamingEventDF.select("eventName",gamingEventDF.eventParams.client_event_time)
testdf = gamingEventDF.select("eventName",to_date(gamingEventDF.eventParams.client_event_time).alias("eventDate"))  #######flattening it out
#testdf = gamingEventDF.select("eventName","eventParams")
testdf.printSchema()
#gamingEventDF.withColumnRenamed("eventName","even").printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- eventName: string (nullable = true)
# -- eventDate: date (nullable = true)
#
# </div>

# %%
# TODO

from pyspark.sql.functions import col, to_date

#eventStream = gamingEventDF.withColumnRenamed("client_event_time","eventDate").filter(col("eventDate").isNotNull()).to_date()

eventsStream = (gamingEventDF
  .withColumn("eventDate",to_date(gamingEventDF.eventParams.client_event_time))
  .filter(col("eventDate").isNotNull())
  .writeStream
  .format("delta")
  .option("checkpointLocation", outputPathBronze + "/_checkpoint") 
  .queryName("bronze_stream")
  .outputMode("append")
  .start(outputPathBronze)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
eventsStream.recentProgress
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">32</span><span class="ansired">]: </span>[{&apos;numInputRows&apos;: 25,
#   &apos;id&apos;: &apos;1c0b63cc-46f5-4090-a1af-9de3b683547c&apos;,
#   &apos;runId&apos;: &apos;a422cecf-944f-4664-93dc-926ce02f89f9&apos;,
#   &apos;name&apos;: &apos;bronze_stream&apos;,
#   &apos;stateOperators&apos;: [],
#   &apos;timestamp&apos;: &apos;2019-11-15T06:53:56.625Z&apos;,
#   &apos;sink&apos;: {&apos;description&apos;: &apos;DeltaSink[dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/bronze]&apos;},
#   &apos;durationMs&apos;: {&apos;getOffset&apos;: 1241,
#    &apos;addBatch&apos;: 10444,
#    &apos;walCommit&apos;: 550,
#    &apos;queryPlanning&apos;: 72,
#    &apos;getBatch&apos;: 77,
#    &apos;triggerExecution&apos;: 13481},
#   &apos;processedRowsPerSecond&apos;: 1.8528125694804713,
#   &apos;sources&apos;: [{&apos;numInputRows&apos;: 25,
#     &apos;startOffset&apos;: None,
#     &apos;processedRowsPerSecond&apos;: 1.8528125694804713,
#     &apos;endOffset&apos;: {&apos;logOffset&apos;: 0},
#     &apos;description&apos;: &apos;FileStreamSource[dbfs:/mnt/training/gaming_data/mobile_streaming_events]&apos;}],
#   &apos;batchId&apos;: 0},
#  {&apos;numInputRows&apos;: 184011,
#   &apos;timestamp&apos;: &apos;2019-11-15T06:54:10.161Z&apos;,
#   &apos;sources&apos;: [{&apos;numInputRows&apos;: 184011,
#     &apos;startOffset&apos;: {&apos;logOffset&apos;: 0},
#     &apos;inputRowsPerSecond&apos;: 13594.193262411349,
#     &apos;description&apos;: &apos;FileStreamSource[dbfs:/mnt/training/gaming_data/mobile_streaming_events]&apos;,
#     &apos;processedRowsPerSecond&apos;: 18476.85510593433,
#     &apos;endOffset&apos;: {&apos;logOffset&apos;: 1}}],
#   &apos;name&apos;: &apos;bronze_stream&apos;,
#   &apos;inputRowsPerSecond&apos;: 13594.193262411349,
#   &apos;sink&apos;: {&apos;description&apos;: &apos;DeltaSink[dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/bronze]&apos;},
#   &apos;id&apos;: &apos;1c0b63cc-46f5-4090-a1af-9de3b683547c&apos;,
#   &apos;runId&apos;: &apos;a422cecf-944f-4664-93dc-926ce02f89f9&apos;,
#   &apos;durationMs&apos;: {&apos;getOffset&apos;: 915,
#    &apos;addBatch&apos;: 7691,
#    &apos;walCommit&apos;: 779,
#    &apos;queryPlanning&apos;: 9,
#    &apos;getBatch&apos;: 57,
#    &apos;triggerExecution&apos;: 9959},
#   &apos;processedRowsPerSecond&apos;: 18476.85510593433,
#   &apos;batchId&apos;: 1,
#   &apos;stateOperators&apos;: []},
#  {&apos;numInputRows&apos;: 209858,
#   &apos;timestamp&apos;: &apos;2019-11-15T06:54:20.121Z&apos;,
#   &apos;sources&apos;: [{&apos;numInputRows&apos;: 209858,
#     &apos;startOffset&apos;: {&apos;logOffset&apos;: 1},
#     &apos;inputRowsPerSecond&apos;: 21070.08032128514,
#     &apos;description&apos;: &apos;FileStreamSource[dbfs:/mnt/training/gaming_data/mobile_streaming_events]&apos;,
#     &apos;processedRowsPerSecond&apos;: 24941.52602804849,
#     &apos;endOffset&apos;: {&apos;logOffset&apos;: 2}}],
#   &apos;name&apos;: &apos;bronze_stream&apos;,
#   &apos;inputRowsPerSecond&apos;: 21070.08032128514,
#   &apos;sink&apos;: {&apos;description&apos;: &apos;DeltaSink[dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/bronze]&apos;},
#   &apos;id&apos;: &apos;1c0b63cc-46f5-4090-a1af-9de3b683547c&apos;,
#   &apos;runId&apos;: &apos;a422cecf-944f-4664-93dc-926ce02f89f9&apos;,
#   &apos;durationMs&apos;: {&apos;getOffset&apos;: 708,
#    &apos;addBatch&apos;: 6504,
#    &apos;walCommit&apos;: 619,
#    &apos;queryPlanning&apos;: 10,
#    &apos;getBatch&apos;: 64,
#    &apos;triggerExecution&apos;: 8414},
#   &apos;processedRowsPerSecond&apos;: 24941.52602804849,
#   &apos;batchId&apos;: 2,
#   &apos;stateOperators&apos;: []},
#  {&apos;numInputRows&apos;: 191977,
#   &apos;timestamp&apos;: &apos;2019-11-15T06:54:28.537Z&apos;,
#   &apos;sources&apos;: [{&apos;numInputRows&apos;: 191977,
#     &apos;startOffset&apos;: {&apos;logOffset&apos;: 2},
#     &apos;inputRowsPerSecond&apos;: 22810.955323193917,
#     &apos;description&apos;: &apos;FileStreamSource[dbfs:/mnt/training/gaming_data/mobile_streaming_events]&apos;,
#     &apos;processedRowsPerSecond&apos;: 22535.156708533865,
#     &apos;endOffset&apos;: {&apos;logOffset&apos;: 3}}],
#   &apos;name&apos;: &apos;bronze_stream&apos;,
#   &apos;inputRowsPerSecond&apos;: 22810.955323193917,
#   &apos;sink&apos;: {&apos;description&apos;: &apos;DeltaSink[dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/bronze]&apos;},
#   &apos;id&apos;: &apos;1c0b63cc-46f5-4090-a1af-9de3b683547c&apos;,
#   &apos;runId&apos;: &apos;a422cecf-944f-4664-93dc-926ce02f89f9&apos;,
#   &apos;durationMs&apos;: {&apos;getOffset&apos;: 996,
#    &apos;addBatch&apos;: 6240,
#    &apos;walCommit&apos;: 690,
#    &apos;queryPlanning&apos;: 8,
#    &apos;getBatch&apos;: 90,
#    &apos;triggerExecution&apos;: 8519},
#   &apos;processedRowsPerSecond&apos;: 22535.156708533865,
#   &apos;batchId&apos;: 3,
#   &apos;stateOperators&apos;: []},
#  {&apos;numInputRows&apos;: 182038,
#   &apos;timestamp&apos;: &apos;2019-11-15T06:54:37.057Z&apos;,
#   &apos;sources&apos;: [{&apos;numInputRows&apos;: 182038,
#     &apos;startOffset&apos;: {&apos;logOffset&apos;: 3},
#     &apos;inputRowsPerSecond&apos;: 21365.962441314554,
#     &apos;description&apos;: &apos;FileStreamSource[dbfs:/mnt/training/gaming_data/mobile_streaming_events]&apos;,
#     &apos;processedRowsPerSecond&apos;: 25909.19442072303,
#     &apos;endOffset&apos;: {&apos;logOffset&apos;: 4}}],
#   &apos;name&apos;: &apos;bronze_stream&apos;,
#   &apos;inputRowsPerSecond&apos;: 21365.962441314554,
#   &apos;sink&apos;: {&apos;description&apos;: &apos;DeltaSink[dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/bronze]&apos;},
#   &apos;id&apos;: &apos;1c0b63cc-46f5-4090-a1af-9de3b683547c&apos;,
#   &apos;runId&apos;: &apos;a422cecf-944f-4664-93dc-926ce02f89f9&apos;,
#   &apos;durationMs&apos;: {&apos;getOffset&apos;: 568,
#    &apos;addBatch&apos;: 5439,
#    &apos;walCommit&apos;: 450,
#    &apos;queryPlanning&apos;: 11,
#    &apos;getBatch&apos;: 57,
#    &apos;triggerExecution&apos;: 7026},
#   &apos;processedRowsPerSecond&apos;: 25909.19442072303,
#   &apos;batchId&apos;: 4,
#   &apos;stateOperators&apos;: []},
#  {&apos;numInputRows&apos;: 183362,
#   &apos;timestamp&apos;: &apos;2019-11-15T06:54:44.085Z&apos;,
#   &apos;sources&apos;: [{&apos;numInputRows&apos;: 183362,
#     &apos;startOffset&apos;: {&apos;logOffset&apos;: 4},
#     &apos;inputRowsPerSecond&apos;: 26090.210586226523,
#     &apos;description&apos;: &apos;FileStreamSource[dbfs:/mnt/training/gaming_data/mobile_streaming_events]&apos;,
#     &apos;processedRowsPerSecond&apos;: 25375.311375588153,
#     &apos;endOffset&apos;: {&apos;logOffset&apos;: 5}}],
#   &apos;name&apos;: &apos;bronze_stream&apos;,
#   &apos;inputRowsPerSecond&apos;: 26090.210586226523,
#   &apos;sink&apos;: {&apos;description&apos;: &apos;DeltaSink[dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/bronze]&apos;},
#   &apos;id&apos;: &apos;1c0b63cc-46f5-4090-a1af-9de3b683547c&apos;,
#   &apos;runId&apos;: &apos;a422cecf-944f-4664-93dc-926ce02f89f9&apos;,
#   &apos;durationMs&apos;: {&apos;getOffset&apos;: 840,
#    &apos;addBatch&apos;: 5304,
#    &apos;walCommit&apos;: 592,
#    &apos;queryPlanning&apos;: 11,
#    &apos;getBatch&apos;: 59,
#    &apos;triggerExecution&apos;: 7226},
#   &apos;processedRowsPerSecond&apos;: 25375.311375588153,
#   &apos;batchId&apos;: 5,
#   &apos;stateOperators&apos;: []},
#  {&apos;numInputRows&apos;: 206219,
#   &apos;timestamp&apos;: &apos;2019-11-15T06:54:51.313Z&apos;,
#   &apos;sources&apos;: [{&apos;numInputRows&apos;: 206219,
#     &apos;startOffset&apos;: {&apos;logOffset&apos;: 5},
#     &apos;inputRowsPerSecond&apos;: 28530.575539568345,
#     &apos;description&apos;: &apos;FileStreamSource[dbfs:/mnt/training/gaming_data/mobile_streaming_events]&apos;,
#     &apos;process

# %%
###IGNORE CELL-for testing purposes
display(gamingEventDF, "bronze_stream")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>eventName</th><th>eventParams</th></tr></thead><tbody><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td></tr><tr><td>scoreAdjustment</td><td>List(minigame5, Fake Application, 712, ios, 1.1.0, 564df38e876647a191d8017de7e8ab46, 2018-11-20T08:23:58.000+0000, null)</td></tr><tr><td>installEvent</td><td>List(minigame6, Fake Application, null, amazon, 1.0.0, eeabaa353feb470c91886789311f3b79, 2018-12-06T21:40:30.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame6, Fake Application, -568, ios, 2.0.1, 3fb2746410ad4b41b3f561bd04370b95, 2019-02-12T10:14:56.000+0000, null)</td></tr><tr><td>installEvent</td><td>List(minigame1, Fake Application, null, ios, 1.3.0, 5c2710b088da4442b8ce17f0aee8ea75, 2019-03-22T08:09:23.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame2, Fake Application, -887, android, 1.3.0, 86af96ab951146b0839e4ad36aea363f, 2019-06-15T17:35:08.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame3, Fake Application, 181, android, 1.3.0, 15ed73598ee2417893a9d75fe591d99a, 2018-11-03T05:19:53.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame2, Fake Application, -284, ios, 2.0.1, da8eb0abc24146418efec20a4152e40f, 2019-05-28T06:22:59.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame4, Fake Application, -547, amazon, 2.0.1, ed231a75693b406b924c52ae022f6e47, 2019-01-14T22:29:09.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame1, Fake Application, 253, ios, 2.0.1, 0790718ba81540d19456d1252df390ab, 2018-08-21T00:18:50.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame5, Fake Application, 48, amazon, 1.1.0, 1bf0857b12ee470dbba2b2f20f6fa681, 2019-02-15T08:44:00.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame1, Fake Application, 769, amazon, 1.3.0, 5b149a63aba044f681e30ec51bb4963b, 2018-12-04T16:58:27.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame2, Fake Application, -353, android, 1.3.0, 847a467d396148a0bba55823ad7f80c3, 2019-06-25T12:44:12.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame5, Fake Application, 108, amazon, 1.1.0, 06a1dc666419408ab395b97d31caf05f, 2018-07-26T19:45:28.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame6, Fake Application, 159, android, 2.0.1, 887a0761cb694e0cb51f9ca64278b43f, 2019-06-16T18:11:34.000+0000, null)</td></tr><tr><td>installEvent</td><td>List(minigame2, Fake Application, null, ios, 1.0.0, d0de9a35881b494a9659af6c5e6495cb, 2018-07-14T19:28:50.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame1, Fake Application, 742, android, 1.0.0, 9136901505d34c869f04638844087033, 2019-04-07T19:47:50.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame4, Fake Application, 570, android, 1.1.0, 82b8ad53f4d24786a6b5853688d852d1, 2019-01-14T23:14:58.000+0000, null)</td></tr><tr><td>scoreAdjustment</td><td>List(minigame2, Fake Application, 89, android, 2.0.1, d8249510a18745abb6deec3c1e9ae424, 2019-07-09T20:54:05.000+0000, null)</td>< ...

# %%
###IGNORE CELL-for testing purposes
eventsStream.awaitTermination(5)
eventsStream.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 3a: Load static data for enrichment
#
# Register a static lookup table to associate `deviceId` with `deviceType` = `{android, ios}`.
#
# While we refer to this as a lookup table, here we'll define it as a DataFrame. This will make it easier for us to define a join on our streaming data in the next step.
#
# Create `deviceLookupDF` from data in `/mnt/training/gaming_data/dimensionData`.

# %%
# TODO
lookupPath = "/mnt/training/gaming_data/dimensionData"

deviceLookupDF = spark.read.format("delta").load(lookupPath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# ### Step 3b: Create a streaming silver Delta table
#
# A silver table is a table that combines, improves, or enriches bronze data.
#
# In this case we will join the bronze streaming data with some static data to add useful information.
#
# #### Steps to complete
#
# Create a new stream by joining `deviceLookupDF` with the bronze table stored at `outputPathBronze` on `deviceId`.
# * Make sure you do a streaming read and write
# * Your selected fields should be:
#   - `eventName`
#   - `device_id`
#   - `client_event_time`
#   - `eventDate`
#   - `deviceType`
# * **NOTE**: some of these fields are nested; alias them to end up with a flat schema
# * Write to `outputPathSilver`
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> Don't forget to checkpoint your stream!

# %%
# flattening tested in cmd 15 test block
#testdf = gamingEventDF.select("eventName",gamingEventDF.eventParams.client_event_time.alias("abc"))  #######flattening it out
##Join example from pyspark documentation
#>>> df.join(df2, 'name', 'inner').drop('age', 'height').collect()
#[Row(name='Bob')]

from pyspark.sql.functions import col

(spark.readStream
  .format("delta")
  .load(outputPathBronze)
 .select("eventName",
         col("eventParams.device_id").alias("device_id"),
         col("eventParams.client_event_time").alias("client_event_time"),
         "eventDate")
 .join(deviceLookupDF, "device_id", "left")
 .writeStream 
 .format("delta")
 .option("checkpointLocation", outputPathSilver + "/_checkpoint")
 .queryName("silver_stream")
 .outputMode("append")
 .start(outputPathSilver))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">27</span><span class="ansired">]: </span>&lt;pyspark.sql.streaming.StreamingQuery at 0x7f8a9e925128&gt;</div>

# %%
display(spark.sql("SELECT * FROM delta.`{}` LIMIT 5".format(outputPathSilver)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>eventName</th><th>client_event_time</th><th>eventDate</th><th>deviceType</th></tr></thead><tbody><tr><td>004a5732188b4b11911c60b5b8eff7f3</td><td>scoreAdjustment</td><td>2019-08-04T00:06:32.000+0000</td><td>2019-08-04</td><td>ios</td></tr><tr><td>00e2d25735e4497399734e4ec44198d9</td><td>scoreAdjustment</td><td>2019-01-21T17:28:11.000+0000</td><td>2019-01-21</td><td>ios</td></tr><tr><td>012a3c37d3bf452dbb07050f5a886946</td><td>scoreAdjustment</td><td>2018-08-18T22:58:39.000+0000</td><td>2018-08-18</td><td>ios</td></tr><tr><td>0176636fc7c94663bfd0afe0ebb9486f</td><td>scoreAdjustment</td><td>2019-04-03T20:23:23.000+0000</td><td>2019-04-03</td><td>android</td></tr><tr><td>0191025a8616492f9a3ba292baddc953</td><td>scoreAdjustment</td><td>2019-07-05T09:55:03.000+0000</td><td>2019-07-05</td><td>android</td></tr></tbody></table></div>

# %%
###IGNORE CELL-for testing purposes
## group by and distinct alternate ways
from pyspark.sql.functions import countDistinct

x = [("week1","id1"),("week2","id1"),("week2","id1"),("week1","id1"),("week1","id2"),("week1","id2"),("week2","id2"),("week3","id3"),("week2","id4")]
y = spark.createDataFrame(x,["year","id"])

display(y.groupby("year").agg(countDistinct("id")).withColumnRenamed("count(DISTINCT id)", "WAU"))
#display(y.distinct().groupby("year").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>WAU</th></tr></thead><tbody><tr><td>week1</td><td>2</td></tr><tr><td>week2</td><td>3</td></tr><tr><td>week3</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 4a: Batch Process a Gold Table from the Silver Table
#
# The company executives want to look at the number of active users by week. They use SQL so our target will be a SQL table backed by a Delta Lake.
#
# The table should have the following columns:
# - `WAU`: count of weekly active users (distinct device IDs grouped by week)
# - `week`: week of year (the appropriate SQL function has been imported for you)
#
# In the first step, calculate these

# %%
###Correct command in NEXT CELL.
### countDistinct didn't work as distinct aggregations aren't supported by streaming dataframes. We could use approx_count_distinct(), and set error margin using rsd parameter.
##whenever we are aggregating streaming data, we cannot append. Because aggregation metrics will change with incoming stream. We have to use complete mode.
from pyspark.sql.functions import weekofyear
from pyspark.sql.functions import countDistinct

(spark.readStream
 .format("Delta")
 .load(outputPathSilver)
 .select(col("device_id"), 
         weekofyear(col("client_event_time")).alias("week"))
.groupBy("week")
.agg(countDistinct("device_id"))
.withColumnRenamed("count(DISTINCT id)", "WAU")
.writeStream
.format("delta")
.option("checkpointLocation", outputPathGold + "/_checkpoint")
.queryName("gold_stream")
.outputMode("complete")
.start(outputPathGold)
)

##see next cell
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2629750047728142&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">     17</span> <span class="ansiyellow">.</span>queryName<span class="ansiyellow">(</span><span class="ansiblue">&quot;gold_stream&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     18</span> <span class="ansiyellow">.</span>outputMode<span class="ansiyellow">(</span><span class="ansiblue">&quot;complete&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 19</span><span class="ansiyellow"> </span><span class="ansiyellow">.</span>start<span class="ansiyellow">(</span>outputPathGold<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     20</span> )
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/streaming.py</span> in <span class="ansicyan">start</span><span class="ansiblue">(self, path, format, outputMode, partitionBy, queryName, **options)</span>
# <span class="ansigreen">   1119</span>             <span class="ansigreen">return</span> self<span class="ansiyellow">.</span>_sq<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>_jwrite<span class="ansiyellow">.</span>start<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1120</span>         <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1121</span><span class="ansiyellow">             </span><span class="ansigreen">return</span> self<span class="ansiyellow">.</span>_sq<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>_jwrite<span class="ansiyellow">.</span>start<span class="ansiyellow">(</span>path<span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1122</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1123</span>     <span class="ansiyellow">@</span>since<span class="ansiyellow">(</span><span class="ansicyan">2.4</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansicyan">__call__</span><span class="ansiblue">(self, *args)</span>
# <span class="ansigreen">   1255</span>         answer <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>gateway_client<span class="ansiyellow">.</span>send_command<span class="ansiyellow">(</span>command<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1256</span>         return_value = get_return_value(
# <span class="ansigreen">-&gt; 1257</span><span class="ansiyellow">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansigreen">   1258</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1259</span>         <span class="ansigreen">for</span> temp_arg <span class="ansigreen">in</span> temp_args<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansicyan">deco</span><span class="ansiblue">(*a, **kw)</span>
# <span class="ansigreen">     67</span>                                              e.java_exception.getStackTrace()))
# <span class="ansigreen">     68</span>             <span class="ansigreen">if</span> s<span class="ansiyellow">.</span>startswith<span class="ansiyellow">(</span><span class="ansiblue">&apos;org.apache.spark.sql.AnalysisException: &apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 69</span><span class="ansiyellow">                 </span><span class="ansigreen">raise</span> AnalysisException<span class="ansiyellow">(</span>s<span class="ansiyellow">.</span>split<span class="ansiyellow">(</span><span class="ansiblue">&apos;: &apos;</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> stackTrace<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     70</span>             <span class="ansigreen">if</span> s<span class="ansiyellow">.</span>startswith<span class="ansiyellow">(</span><span class="ansiblue">&apos;org.apache.spark.sql.catalyst.analysis&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">     71</span>                 <span class="ansigreen">raise</span> AnalysisException<span class="ansiyellow">(</span>s<span class="ansiyellow">.</span>split<span class="ansiyellow">(</span><span class="ansiblue">&apos;: &apos;</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> stackTrace<span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">AnalysisException</span>: &apos;Distinct aggregations are not supported on streaming DataFrames/Datasets. Consider using approx_count_distinct() instead.;;\nAggregate [week#37968], [week#37968, count(distinct device_id#37958) AS count(DISTINCT device_id)#37974L]\n+- Project [device_id#37958, weekofyear(cast(client_event_time#37960 as date)) AS week#37968]\n   +- StreamingRelation DataSource(org.apache.spark.sql.SparkSession@661f88be,Delta,List(),None,List(),None,Map(path -&gt; dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/silver),None), tahoe, [device_id#37958, eventName#37959, client_event_time#37960, eventDate#37961, deviceType#37962]\n&apos;</div>

# %%
# TODO
##whenever we are aggregating streaming data, we cannot append. Because aggregation metrics will change with incoming stream. We have to use complete mode.
from pyspark.sql.functions import weekofyear

(spark.readStream
 .format("Delta")
 .load(outputPathSilver)
 .select(col("device_id"), 
         weekofyear(col("client_event_time")).alias("week")).distinct()
 .groupBy("week")
 .count()
 .withColumnRenamed("count", "WAU")
.writeStream
.format("delta")
.option("checkpointLocation", outputPathGold + "/_checkpoint")
.queryName("gold_stream")
.outputMode("complete")
.start(outputPathGold)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">37</span><span class="ansired">]: </span>&lt;pyspark.sql.streaming.StreamingQuery at 0x7f8a8045ceb8&gt;</div>

# %%
display(dbutils.fs.ls(outputPathGold))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/_checkpoint/</td><td>_checkpoint/</td><td>0</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-0942a85d-f1d5-4361-8bad-86035364ba3a-c000.snappy.parquet</td><td>part-00000-0942a85d-f1d5-4361-8bad-86035364ba3a-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-157c7c2d-89e5-4f10-acb3-67200faaa64d-c000.snappy.parquet</td><td>part-00000-157c7c2d-89e5-4f10-acb3-67200faaa64d-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-2c4ffdf0-8168-4959-aa9e-87c10dbba502-c000.snappy.parquet</td><td>part-00000-2c4ffdf0-8168-4959-aa9e-87c10dbba502-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-2d582d9f-d41c-4729-b793-7e448a380c13-c000.snappy.parquet</td><td>part-00000-2d582d9f-d41c-4729-b793-7e448a380c13-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-42300cb5-8b22-4fea-9bc0-a955e5572067-c000.snappy.parquet</td><td>part-00000-42300cb5-8b22-4fea-9bc0-a955e5572067-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-516f87c1-36bc-46e1-9aa8-6f2b977697ea-c000.snappy.parquet</td><td>part-00000-516f87c1-36bc-46e1-9aa8-6f2b977697ea-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-559d8943-7b6c-4764-9a68-7f3b19123e1c-c000.snappy.parquet</td><td>part-00000-559d8943-7b6c-4764-9a68-7f3b19123e1c-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-602145d0-7cb2-42df-a37e-c8fe67a1bf52-c000.snappy.parquet</td><td>part-00000-602145d0-7cb2-42df-a37e-c8fe67a1bf52-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-66bf976d-5560-4b5d-afad-3962f5cafa54-c000.snappy.parquet</td><td>part-00000-66bf976d-5560-4b5d-afad-3962f5cafa54-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-725d8fa5-b471-4c58-b245-bf85884d7c86-c000.snappy.parquet</td><td>part-00000-725d8fa5-b471-4c58-b245-bf85884d7c86-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-74f80a84-65cb-4536-bad9-4035e5bad76e-c000.snappy.parquet</td><td>part-00000-74f80a84-65cb-4536-bad9-4035e5bad76e-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-941aa4cc-9e08-438b-8fed-fdc930020892-c000.snappy.parquet</td><td>part-00000-941aa4cc-9e08-438b-8fed-fdc930020892-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-961a3453-134a-4b81-bb8c-a854d051505c-c000.snappy.parquet</td><td>part-00000-961a3453-134a-4b81-bb8c-a854d051505c-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-97bc2f58-0e54-4fd3-8c36-2174e7eecedd-c000.snappy.parquet</td><td>part-00000-97bc2f58-0e54-4fd3-8c36-2174e7eecedd-c000.snappy.parquet</td><td>357</td></tr><tr><td>dbfs:/user/akarsh.pydimarri@wavicledata.com/capstone/gaming/gold/part-00000-a46397c5-3712-4a43-9e5d-2fa5b0cdefe6-c000.snappy.parquet</td><td>part-00000-a46397c5-3712-4a43-9e5d-2fa5b0cdefe6-c000.snappy.parquet</td><td>357</td></tr><tr><t ...

# %%
display(spark.sql("SELECT * FROM delta.`{}` LIMIT 5".format(outputPathGold)))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>week</th><th>WAU</th></tr></thead><tbody><tr><td>40</td><td>54671</td></tr><tr><td>20</td><td>79488</td></tr><tr><td>31</td><td>110150</td></tr><tr><td>25</td><td>109648</td></tr><tr><td>49</td><td>54626</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
#
# ### Step 4b: Register Gold SQL Table
#
# By linking the Spark SQL table with the Delta Lake file path, we will always get results from the most current valid version of the streaming table.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> It may take some time for the previous streaming operations to start.
#
# Once they have started register a SQL table against the gold Delta Lake path.
#
# * tablename: `mobile_events_delta_gold`
# * table Location: `outputPathGold`

# %%
# TODO
spark.sql("""
   CREATE TABLE IF NOT EXISTS mobile_events_delta_gold
   USING DELTA
   LOCATION '{}'
  """.format(outputPathGold))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">42</span><span class="ansired">]: </span>DataFrame[]</div>

# %% [markdown]
# -sandbox
# ### Step 4c: Visualization
#
# The company executives are visual people: they like pretty charts.
#
# Create a bar chart out of `mobile_events_delta_gold` where the horizontal axis is month and the vertical axis is WAU.
#
# Under <b>Plot Options</b>, use the following:
# * <b>Keys:</b> `week`
# * <b>Values:</b> `WAU`
#
# In <b>Display type</b>, use <b>Bar Chart</b> and click <b>Apply</b>.
#
# <img src="https://s3-us-west-2.amazonaws.com/files.training.databricks.com/images/eLearning/Delta/plot-options-bar.png"/>
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> order by `week` to seek time-based patterns.

# %%
# %sql
SELECT * FROM mobile_events_delta_gold
order by week
;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>week</th><th>WAU</th></tr></thead><tbody><tr><td>1</td><td>55064</td></tr><tr><td>2</td><td>54883</td></tr><tr><td>3</td><td>55075</td></tr><tr><td>4</td><td>54996</td></tr><tr><td>5</td><td>55290</td></tr><tr><td>6</td><td>54885</td></tr><tr><td>7</td><td>54670</td></tr><tr><td>8</td><td>55190</td></tr><tr><td>9</td><td>55120</td></tr><tr><td>10</td><td>54944</td></tr><tr><td>11</td><td>54879</td></tr><tr><td>12</td><td>55005</td></tr><tr><td>13</td><td>55174</td></tr><tr><td>14</td><td>55281</td></tr><tr><td>15</td><td>55094</td></tr><tr><td>16</td><td>55239</td></tr><tr><td>17</td><td>55019</td></tr><tr><td>18</td><td>54538</td></tr><tr><td>19</td><td>54949</td></tr><tr><td>20</td><td>79496</td></tr><tr><td>21</td><td>110306</td></tr><tr><td>22</td><td>109771</td></tr><tr><td>23</td><td>110233</td></tr><tr><td>24</td><td>110150</td></tr><tr><td>25</td><td>109664</td></tr><tr><td>26</td><td>109325</td></tr><tr><td>27</td><td>110217</td></tr><tr><td>28</td><td>109581</td></tr><tr><td>29</td><td>110155</td></tr><tr><td>30</td><td>110101</td></tr><tr><td>31</td><td>110161</td></tr><tr><td>32</td><td>110474</td></tr><tr><td>33</td><td>109981</td></tr><tr><td>34</td><td>109815</td></tr><tr><td>35</td><td>60024</td></tr><tr><td>37</td><td>50133</td></tr><tr><td>38</td><td>54792</td></tr><tr><td>39</td><td>55089</td></tr><tr><td>40</td><td>54675</td></tr><tr><td>41</td><td>55304</td></tr><tr><td>42</td><td>55124</td></tr><tr><td>43</td><td>55199</td></tr><tr><td>44</td><td>54986</td></tr><tr><td>45</td><td>55346</td></tr><tr><td>46</td><td>55070</td></tr><tr><td>47</td><td>54683</td></tr><tr><td>48</td><td>54816</td></tr><tr><td>49</td><td>54631</td></tr><tr><td>50</td><td>55053</td></tr><tr><td>51</td><td>54646</td></tr><tr><td>52</td><td>54793</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 5: Wrap-up
#
# * Stop streams

# %%
for s in spark.streams.active:
  s.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Congratulations: ALL DONE!!

# %% [markdown]
# -sandbox
# &copy; 2019 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
